# %%
a = 123
type(a)
# Out:
# int

# %%
16 **0.5
# Out:
# 4.0

# %%
7/3
7//3
# Out:
# 2

# %%
a = 1
a = a+1

print(a)
# Out:
# 2

# %%
a = 1
a += 1 # a = a+1
print(a)

a -=1 # a = a-1
a *=1 # a = a*1
a /=1 # a = a/1
print(a)
# Out:
# 2
# 1.0

# %%
"Life is too short, you need Python"
# Out:
# 'Life is too short, you need Python'

# %%
'Life is too short, you need Python'
# Out:
# 'Life is too short, you need Python'

# %%
"""Life is too short, you need Python"""
# Out:
# 'Life is too short, you need Python'

# %%
food = "Python's favorite food is perl"
food
# Out:
# "Python's favorite food is perl"

# %%
food = "Python\"s favorite food is perl"
food
# Out:
#   Cell In[17], line 1
#     food = "Python"s favorite food is perl"
#                                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print(" - "*30)
print("python")
print(" - "*30)
# Out:
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# python
#  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -

# %%
a = "dkfkajdfa"
len(a)
# Out:
# 9

# %%
a ="king"
a[3]
# Out:
# 'g'

# %%
a = "abcdefghijklmnop"
print(a[1:7:2])
# Out:
# bdf

# %%
number = [1,2,3,4,5]
for i in number:
    print(f"i eat {i} apples")
# Out:
# i eat 1 apples
# i eat 2 apples
# i eat 3 apples
# i eat 4 apples
# i eat 5 apples

# %%
i=3
print(f"i eat {i} apples")
# Out:
# i eat 3 apples

# %%
print("I ate {0} apples, so I was sick for {1}, days".format(3, 5))
# Out:
# I ate 3 apples, so I was sick for 5, days

# %%
a = "hobby"
print(a.find("b"))
# Out:
# 2

# %%
print(".".join("abcd"))
# Out:
# a.b.c.d

# %%
print("life", "is","short", sep="\n")
# Out:
# life
# is
# short

# %%
a = "    hi "
print(a)
print(a.strip())
print(a.lstrip())
print(a.rstrip())
# Out:
#     hi
# hi
# hi
#     hi

# %%
a = "life is short"
print(a.replace("life", "your leg"))
# Out:
# your leg is short

# %%
a = "Life is too short"
print(a.split())
# Out:
# ['Life', 'is', 'too', 'short']
